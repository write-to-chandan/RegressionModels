# %% [markdown]
# ## Random Forest classifier

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import train_test_split
import pandas as pd
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation
from sklearn.preprocessing import OneHotEncoder
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn import datasets
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error


def condition(r):
    if (0 <= r <= 5):
        label = 4
    else:
        label = 7
    return label

# %%
df = pd.read_csv("/Users/chandankumar/Documents/Datasets/WineData3a.csv", header=0)
df.head()
# Out:
#    fixed  volatile  citric  sugar  chlorides  free  total  density    pH  \
# 0    7.4      0.70    0.00    1.9      0.076  11.0   34.0   0.9978  3.51
# 1    7.8      0.88    0.00    2.6      0.098  25.0   67.0   0.9968  3.20
# 2    7.8      0.76    0.04    2.3      0.092  15.0   54.0   0.9970  3.26
# 3   11.2      0.28    0.56    1.9      0.075  17.0   60.0   0.9980  3.16
# 4    7.4      0.70    0.00    1.9      0.076  11.0   34.0   0.9978  3.51
#
#    sulphates  alcohol  quality
# 0       0.56      9.4        5
# 1       0.68      9.8        5
# 2       0.65      9.8        5
# 3       0.58      9.8        6
# 4       0.56      9.4        5

# %%
df["quality_class"] = df['quality'].apply(lambda x: condition(x))
df.head()
# Out:
#    fixed  volatile  citric  sugar  chlorides  free  total  density    pH  \
# 0    7.4      0.70    0.00    1.9      0.076  11.0   34.0   0.9978  3.51
# 1    7.8      0.88    0.00    2.6      0.098  25.0   67.0   0.9968  3.20
# 2    7.8      0.76    0.04    2.3      0.092  15.0   54.0   0.9970  3.26
# 3   11.2      0.28    0.56    1.9      0.075  17.0   60.0   0.9980  3.16
# 4    7.4      0.70    0.00    1.9      0.076  11.0   34.0   0.9978  3.51
#
#    sulphates  alcohol  quality  quality_class
# 0       0.56      9.4        5              4
# 1       0.68      9.8        5              4
# 2       0.65      9.8        5              4
# 3       0.58      9.8        6              7
# 4       0.56      9.4        5              4

# %%
# X, y = make_classification(n_samples=1000, n_features=12, n_informative=2, n_redundant=0, random_state=0, shuffle=False)

# %%
# y

# %%
X = df[['fixed', 'volatile', 'citric', 'sugar', 'chlorides', 'free', 'total',
       'density', 'pH', 'sulphates', 'alcohol']]
y = df['quality_class']

# %%
lst = [0.5, 0.55, 0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9, 0.95]
for ls in lst:
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=(1-ls), random_state=0)
    rfClassifier = RandomForestClassifier(max_depth=2, random_state=0)
    rfClassifier.fit(X_train, y_train)
    predictions = rfClassifier.predict(X_test)
    score = rfClassifier.score(X_test, y_test)
    # Use score method to get accuracy of model
    print("\n---------------------------------")
    print("Test Size: ", round(1-ls,2))
    print("-----------------------------------")
    print("Accuracy: ", score)
    # print(score)
    cm = metrics.confusion_matrix(y_test, predictions)
    tn, fp, fn, tp = metrics.confusion_matrix(y_test, predictions).ravel()
#     print("TN: ", tn)
#     print("FP: ", fp)
#     print("FN: ", fn)
#     print("TP: ", tp)
    print("Confusion Matrix: ")
    print(cm)
    sensitivity_or_recall = tp/(tp+fn)
    specificity = tn/(tn+fp)
    precison = tp/(tp+fp)
    F1Score = (2*tp)/((2*tp)+fp+fn)
    print("Recall: ", sensitivity_or_recall)
    print("Specificity: ", specificity)
    print("Precision: ", precison)
    print("F1 - Score: ", F1Score )
    r2 = r2_score(y_test, predictions)
    print("R Squared: ", r2)
    # print(r2)
    mse = mean_squared_error(y_test, predictions)
    print("Root Mean Squared Error", np.sqrt(mse))
# Out:
# ---------------------------------
# Test Size:  0.5
# -----------------------------------
# Accuracy:  0.69875
# Confusion Matrix:
# [[217 159]
#  [ 82 342]]
# Recall:  0.8066037735849056
# Specificity:  0.5771276595744681
# Precision:  0.6826347305389222
# F1 - Score:  0.7394594594594595
# R Squared:  -0.2093536732236052
# Root Mean Squared Error 1.6465873800075113
#
# ---------------------------------
# Test Size:  0.45
# -----------------------------------
# Accuracy:  0.7013888888888888
# Confusion Matrix:
# [[197 143]
#  [ 72 308]]
# Recall:  0.8105263157894737
# Specificity:  0.5794117647058824
# Precision:  0.6829268292682927
# F1 - Score:  0.7412755716004813
# R Squared:  -0.19814241486068118
# Root Mean Squared Error 1.6393596310755
#
# ---------------------------------
# Test Size:  0.4
# -----------------------------------
# Accuracy:  0.721875
# Confusion Matrix:
# [[186 120]
#  [ 58 276]]
# Recall:  0.8263473053892215
# Specificity:  0.6078431372549019
# Precision:  0.696969696969697
# F1 - Score:  0.7561643835616438
# R Squared:  -0.11463347814175573
# Root Mean Squared Error 1.582126733229674
#
# ---------------------------------
# Test Size:  0.35
# -----------------------------------
# Accuracy:  0.7232142857142857
# Confusion Matrix:
# [[169  97]
#  [ 58 236]]
# Recall:  0.8027210884353742
# Specificity:  0.6353383458646616
# Precision:  0.7087087087087087
# F1 - Score:  0.7527910685805422
# R Squared:  -0.1099176512710347
# Root Mean Squared Error 1.5783128424274537
#
# ---------------------------------
# Test Size:  0.3
# -----------------------------------
# Accuracy:  0.6958333333333333
# Confusion Matrix:
# [[125 101]
#  [ 45 209]]
# Recall:  0.8228346456692913
# Specificity:  0.5530973451327433
# Precision:  0.6741935483870968
# F1 - Score:  0.7411347517730497
# R Squared:  -0.22082084872134322
# Root Mean Squared Error 1.6545392107774297
#
# ---------------------------------
# Test Size:  0.25
# -----------------------------------
# Accuracy:  0.7175
# Confusion Matrix:
# [[118  67]
#  [ 46 169]]
# Recall:  0.786046511627907
# Specificity:  0.6378378378378379
# Precision:  0.7161016949152542
# F1 - Score:  0.7494456762749445
# R Squared:  -0.1363922061596481
# Root Mean Squared Error 1.5945218719101975
#
# ---------------------------------
# Test Size:  0.2
# -----------------------------------
# Accuracy:  0.703125
# Confusion Matrix:
# [[ 90  58]
#  [ 37 135]]
# Recall:  0.7848837209302325
# Specificity:  0.6081081081081081
# Precision:  0.6994818652849741
# F1 - Score:  0.7397260273972602
# R Squared:  -0.1942174732872406
# Root Mean Squared Error 1.6345871038277526
#
# ---------------------------------
# Test Size:  0.15
# -----------------------------------
# Accuracy:  0.7208333333333333
# Confusion Matrix:
# [[ 65  40]
#  [ 27 108]]
# Recall:  0.8
# Specificity:  0.6190476190476191
# Precision:  0.7297297297297297
# F1 - Score:  0.7632508833922261
# R Squared:  -0.13439153439153428
# Root Mean Squared Error 1.585086748414736
#
# ---------------------------------
# Test Size:  0.1
# -----------------------------------
# Accuracy:  0.74375
# Confusion Matrix:
# [[48 23]
#  [18 71]]
# Recall:  0.797752808988764
# Specificity:  0.676056338028169
# Precision:  0.7553191489361702
# F1 - Score:  0.7759562841530054
# R Squared:  -0.038138946035765064
# Root Mean Squared Error 1.518634254848744
#
# ---------------------------------
# Test Size:  0.05
# -----------------------------------
# Accuracy:  0.725
# Confusion Matrix:
# [[26 11]
#  [11 32]]
# Recall:  0.7441860465116279
# Specificity:  0.7027027027027027
# Precision:  0.7441860465116279
# F1 - Score:  0.7441860465116279
# R Squared:  -0.10622250157133872
# Root Mean Squared Error 1.5732132722552274
# /anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
lst = [0.5, 0.55, 0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9, 0.95]
for ls in lst:
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=(1-ls), random_state=0)
    rfClassifier = RandomForestClassifier(max_depth=2, random_state=0)
    rfClassifier.fit(X_train, y_train)
    predictions = rfClassifier.predict(X_test)
    score = rfClassifier.score(X_test, y_test)
    # Use score method to get accuracy of model
    print("\n---------------------------------")
    print("Test Size: ", round(1-ls,2))
    print("-----------------------------------")
    print("Accuracy: ", score)
    # print(score)
    cm = metrics.confusion_matrix(y_test, predictions)
    tn, fp, fn, tp = metrics.confusion_matrix(y_test, predictions).ravel()
    print("TN: ", tn)
    print("FP: ", fp)
    print("FN: ", fn)
    print("TP: ", tp)
    print("Confusion Matrix: ")
    print(cm)
    sensitivity_or_recall = tp/(tp+fn)
    specificity = tn/(tn+fp)
    precison = tp/(tp+fp)
    F1Score = (2*tp)/((2*tp)+fp+fn)
    print("Recall: ", sensitivity_or_recall)
    print("Specificity: ", specificity)
    print("Precision: ", precison)
    print("F1 - Score: ", F1Score )
    r2 = r2_score(y_test, predictions)
    print("R Squared: ", r2)
    # print(r2)
    mse = mean_squared_error(y_test, predictions)
    print("Root Mean Squared Error", np.sqrt(mse))
# Out:
# /anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# ---------------------------------
# Test Size:  0.5
# -----------------------------------
# Accuracy:  0.69875
# TN:  217
# FP:  159
# FN:  82
# TP:  342
# Confusion Matrix:
# [[217 159]
#  [ 82 342]]
# Recall:  0.8066037735849056
# Specificity:  0.5771276595744681
# Precision:  0.6826347305389222
# F1 - Score:  0.7394594594594595
# R Squared:  -0.2093536732236052
# Root Mean Squared Error 1.6465873800075113
#
# ---------------------------------
# Test Size:  0.45
# -----------------------------------
# Accuracy:  0.7013888888888888
# TN:  197
# FP:  143
# FN:  72
# TP:  308
# Confusion Matrix:
# [[197 143]
#  [ 72 308]]
# Recall:  0.8105263157894737
# Specificity:  0.5794117647058824
# Precision:  0.6829268292682927
# F1 - Score:  0.7412755716004813
# R Squared:  -0.19814241486068118
# Root Mean Squared Error 1.6393596310755
#
# ---------------------------------
# Test Size:  0.4
# -----------------------------------
# Accuracy:  0.721875
# TN:  186
# FP:  120
# FN:  58
# TP:  276
# Confusion Matrix:
# [[186 120]
#  [ 58 276]]
# Recall:  0.8263473053892215
# Specificity:  0.6078431372549019
# Precision:  0.696969696969697
# F1 - Score:  0.7561643835616438
# R Squared:  -0.11463347814175573
# Root Mean Squared Error 1.582126733229674
#
# ---------------------------------
# Test Size:  0.35
# -----------------------------------
# Accuracy:  0.7232142857142857
# TN:  169
# FP:  97
# FN:  58
# TP:  236
# Confusion Matrix:
# [[169  97]
#  [ 58 236]]
# Recall:  0.8027210884353742
# Specificity:  0.6353383458646616
# Precision:  0.7087087087087087
# F1 - Score:  0.7527910685805422
# R Squared:  -0.1099176512710347
# Root Mean Squared Error 1.5783128424274537
#
# ---------------------------------
# Test Size:  0.3
# -----------------------------------
# Accuracy:  0.6958333333333333
# TN:  125
# FP:  101
# FN:  45
# TP:  209
# Confusion Matrix:
# [[125 101]
#  [ 45 209]]
# Recall:  0.8228346456692913
# Specificity:  0.5530973451327433
# Precision:  0.6741935483870968
# F1 - Score:  0.7411347517730497
# R Squared:  -0.22082084872134322
# Root Mean Squared Error 1.6545392107774297
#
# ---------------------------------
# Test Size:  0.25
# -----------------------------------
# Accuracy:  0.7175
# TN:  118
# FP:  67
# FN:  46
# TP:  169
# Confusion Matrix:
# [[118  67]
#  [ 46 169]]
# Recall:  0.786046511627907
# Specificity:  0.6378378378378379
# Precision:  0.7161016949152542
# F1 - Score:  0.7494456762749445
# R Squared:  -0.1363922061596481
# Root Mean Squared Error 1.5945218719101975
#
# ---------------------------------
# Test Size:  0.2
# -----------------------------------
# Accuracy:  0.703125
# TN:  90
# FP:  58
# FN:  37
# TP:  135
# Confusion Matrix:
# [[ 90  58]
#  [ 37 135]]
# Recall:  0.7848837209302325
# Specificity:  0.6081081081081081
# Precision:  0.6994818652849741
# F1 - Score:  0.7397260273972602
# R Squared:  -0.1942174732872406
# Root Mean Squared Error 1.6345871038277526
#
# ---------------------------------
# Test Size:  0.15
# -----------------------------------
# Accuracy:  0.7208333333333333
# TN:  65
# FP:  40
# FN:  27
# TP:  108
# Confusion Matrix:
# [[ 65  40]
#  [ 27 108]]
# Recall:  0.8
# Specificity:  0.6190476190476191
# Precision:  0.7297297297297297
# F1 - Score:  0.7632508833922261
# R Squared:  -0.13439153439153428
# Root Mean Squared Error 1.585086748414736
#
# ---------------------------------
# Test Size:  0.1
# -----------------------------------
# Accuracy:  0.74375
# TN:  48
# FP:  23
# FN:  18
# TP:  71
# Confusion Matrix:
# [[48 23]
#  [18 71]]
# Recall:  0.797752808988764
# Specificity:  0.676056338028169
# Precision:  0.7553191489361702
# F1 - Score:  0.7759562841530054
# R Squared:  -0.038138946035765064
# Root Mean Squared Error 1.518634254848744
#
# ---------------------------------
# Test Size:  0.05
# -----------------------------------
# Accuracy:  0.725
# TN:  26
# FP:  11
# FN:  11
# TP:  32
# Confusion Matrix:
# [[26 11]
#  [11 32]]
# Recall:  0.7441860465116279
# Specificity:  0.7027027027027027
# Precision:  0.7441860465116279
# F1 - Score:  0.7441860465116279
# R Squared:  -0.10622250157133872
# Root Mean Squared Error 1.5732132722552274
