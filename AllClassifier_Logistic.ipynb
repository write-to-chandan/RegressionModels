# %% [markdown]
# ## Logistic Regression Classifier

# %%
from sklearn.preprocessing import OneHotEncoder
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn import datasets
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

def condition(r):
    if (0 <= r <= 5):
        label = 4
    else:
        label = 7
    return label



# def condition(r):
#     if (0 <= r <= 5):
#         label = "averge"
#     else:
#         label = "better"
#     return label


# def transData(data):
#     return data.rdd.map(lambda r: [Vectors.dense(r[:-1]), r[-1]]).toDF(['features', 'label'])

# df_C["quality_class"] = df_C['quality'].apply(lambda x: condition(x))

# %%
df = pd.read_csv("/Users/chandankumar/Documents/Datasets/WineData3a.csv", header=0)
df.head()
# Out:
#    fixed  volatile  citric  sugar  chlorides  free  total  density    pH  \
# 0    7.4      0.70    0.00    1.9      0.076  11.0   34.0   0.9978  3.51
# 1    7.8      0.88    0.00    2.6      0.098  25.0   67.0   0.9968  3.20
# 2    7.8      0.76    0.04    2.3      0.092  15.0   54.0   0.9970  3.26
# 3   11.2      0.28    0.56    1.9      0.075  17.0   60.0   0.9980  3.16
# 4    7.4      0.70    0.00    1.9      0.076  11.0   34.0   0.9978  3.51
#
#    sulphates  alcohol  quality
# 0       0.56      9.4        5
# 1       0.68      9.8        5
# 2       0.65      9.8        5
# 3       0.58      9.8        6
# 4       0.56      9.4        5

# %%
df.quality.unique()
# Out:
# array([5, 6, 7, 4, 8, 3])

# %%
df["quality_class"] = df['quality'].apply(lambda x: condition(x))
df.head()
# Out:
#    fixed  volatile  citric  sugar  chlorides  free  total  density    pH  \
# 0    7.4      0.70    0.00    1.9      0.076  11.0   34.0   0.9978  3.51
# 1    7.8      0.88    0.00    2.6      0.098  25.0   67.0   0.9968  3.20
# 2    7.8      0.76    0.04    2.3      0.092  15.0   54.0   0.9970  3.26
# 3   11.2      0.28    0.56    1.9      0.075  17.0   60.0   0.9980  3.16
# 4    7.4      0.70    0.00    1.9      0.076  11.0   34.0   0.9978  3.51
#
#    sulphates  alcohol  quality  quality_class
# 0       0.56      9.4        5              4
# 1       0.68      9.8        5              4
# 2       0.65      9.8        5              4
# 3       0.58      9.8        6              7
# 4       0.56      9.4        5              4

# %%
X = df[['fixed', 'volatile', 'citric', 'sugar', 'chlorides', 'free', 'total',
       'density', 'pH', 'sulphates', 'alcohol']]
y = df['quality_class']

# %%
lst = [0.5, 0.55, 0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9, 0.95]
for ls in lst:
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=(1-ls), random_state=0)
    logisticRegr = LogisticRegression()
    logisticRegr.fit(X_train, y_train)
    predictions = logisticRegr.predict(X_test)
    score = logisticRegr.score(X_test, y_test)
    # Use score method to get accuracy of model
    print("\n---------------------------------")
    print("Test Size: ", round(1-ls,2))
    print("-----------------------------------")
    print("Accuracy: ", score)
    # print(score)
    cm = metrics.confusion_matrix(y_test, predictions)
    tn, fp, fn, tp = metrics.confusion_matrix(y_test, predictions).ravel()
    print("Confusion Matrix: ")
    print(cm)
    sensitivity_or_recall = tp/(tp+fn)
    specificity = tn/(tn+fp)
    precison = tp/(tp+fp)
    F1Score = (2*tp)/((2*tp)+fp+fn)
    print("Recall: ", sensitivity_or_recall)
    print("Specificity: ", specificity)
    print("Precision: ", precison)
    print("F1 - Score: ", F1Score )
    r2 = r2_score(y_test, predictions)
    print("R Squared: ", r2)
    # print(r2)
    mse = mean_squared_error(y_test, predictions)
    print("Root Mean Squared Error", np.sqrt(mse))
# Out:
# ---------------------------------
# Test Size:  0.5
# -----------------------------------
# Accuracy:  0.72875
# Confusion Matrix:
# [[256 120]
#  [ 97 327]]
# Recall:  0.7712264150943396
# Specificity:  0.6808510638297872
# Precision:  0.7315436241610739
# F1 - Score:  0.7508610792192881
# R Squared:  -0.08892011240465703
# Root Mean Squared Error 1.5624499991999745
#
# ---------------------------------
# Test Size:  0.45
# -----------------------------------
# Accuracy:  0.7361111111111112
# Confusion Matrix:
# [[231 109]
#  [ 81 299]]
# Recall:  0.7868421052631579
# Specificity:  0.6794117647058824
# Precision:  0.7328431372549019
# F1 - Score:  0.7588832487309645
# R Squared:  -0.05882352941176472
# Root Mean Squared Error 1.541103500742244
#
# ---------------------------------
# Test Size:  0.4
# -----------------------------------
# Accuracy:  0.7375
# Confusion Matrix:
# [[205 101]
#  [ 67 267]]
# Recall:  0.7994011976047904
# Specificity:  0.6699346405228758
# Precision:  0.7255434782608695
# F1 - Score:  0.7606837606837606
# R Squared:  -0.052013619819185175
# Root Mean Squared Error 1.5370426148939398
#
# ---------------------------------
# Test Size:  0.35
# -----------------------------------
# Accuracy:  0.7428571428571429
# Confusion Matrix:
# [[184  82]
#  [ 62 232]]
# Recall:  0.7891156462585034
# Specificity:  0.6917293233082706
# Precision:  0.7388535031847133
# F1 - Score:  0.7631578947368421
# R Squared:  -0.031149301825993403
# Root Mean Squared Error 1.52127765851133
#
# ---------------------------------
# Test Size:  0.3
# -----------------------------------
# Accuracy:  0.7416666666666667
# Confusion Matrix:
# [[157  69]
#  [ 55 199]]
# Recall:  0.7834645669291339
# Specificity:  0.6946902654867256
# Precision:  0.7425373134328358
# F1 - Score:  0.7624521072796935
# R Squared:  -0.036861542749633935
# Root Mean Squared Error 1.5247950681976907
#
# ---------------------------------
# Test Size:  0.25
# -----------------------------------
# Accuracy:  0.755
# Confusion Matrix:
# [[134  51]
#  [ 47 168]]
# Recall:  0.7813953488372093
# Specificity:  0.7243243243243244
# Precision:  0.7671232876712328
# F1 - Score:  0.7741935483870968
# R Squared:  0.014456316781898071
# Root Mean Squared Error 1.4849242404917498
#
# ---------------------------------
# Test Size:  0.2
# -----------------------------------
# Accuracy:  0.75625
# Confusion Matrix:
# [[107  41]
#  [ 37 135]]
# Recall:  0.7848837209302325
# Specificity:  0.722972972972973
# Precision:  0.7670454545454546
# F1 - Score:  0.7758620689655172
# R Squared:  0.019484600879949743
# Root Mean Squared Error 1.4811313243598625
#
# ---------------------------------
# Test Size:  0.15
# -----------------------------------
# Accuracy:  0.7541666666666667
# Confusion Matrix:
# [[ 74  31]
#  [ 28 107]]
# Recall:  0.7925925925925926
# Specificity:  0.7047619047619048
# Precision:  0.7753623188405797
# F1 - Score:  0.7838827838827839
# R Squared:  0.0010582010582010914
# Root Mean Squared Error 1.4874474780643516
#
# ---------------------------------
# Test Size:  0.1
# -----------------------------------
# Accuracy:  0.76875
# Confusion Matrix:
# [[51 20]
#  [17 72]]
# Recall:  0.8089887640449438
# Specificity:  0.7183098591549296
# Precision:  0.782608695652174
# F1 - Score:  0.7955801104972375
# R Squared:  0.06314290235796804
# Root Mean Squared Error 1.4426538046253508
#
# ---------------------------------
# Test Size:  0.05
# -----------------------------------
# Accuracy:  0.775
# Confusion Matrix:
# [[27 10]
#  [ 8 35]]
# Recall:  0.813953488372093
# Specificity:  0.7297297297297297
# Precision:  0.7777777777777778
# F1 - Score:  0.7954545454545454
# R Squared:  0.09490886235072282
# Root Mean Squared Error 1.4230249470757708
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
